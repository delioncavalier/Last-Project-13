# %% [markdown]
# # <b>File Handling 😹</b>
# ### File handling pada Python adalah proses dalam membuat, membaca, mengubah, dan menghapus file pada sistem. Python menyediakan fungsi utama dalam file handling, yaitu ```open()```. Fungsi ```open()``` mengambil dua parameter, yaitu ```filename``` dan ```mode```.

# %% [markdown]
# ---

# %% [markdown]
# ## Mode dalam fungsi ```open()``` yang sering digunakan sebagai berikut:
# ### 1. 'r' => <b>(Read) </b> berfungsi untuk membuka dan membaca sebuah file.
# ### 2. 'a' => <b>(Append)</b> berfungsi untuk membuka file untuk ditambahkan sebuah data, jika belum ada maka Python akan membuat secara otomatis.
# ### 3. 'w' => <b>(Write)</b> berfungsi untuk membuka file untuk ditulis sebuah data, jika tidak ada maka akan dibuat secara otomatis.
#
#
# ### Setelah membuka file dengan fungsi ```open()```, kita perlu menutupnya dengan fungsi ```close()```. Tujuannya adalah untuk menjaga resource memori dan mencegah kebocoran memori.

# %% [markdown]
# ---

# %% [markdown]
# # Menyimpan data dengan database sederhana menggunakan CSV

# %% [markdown]
# ### CSV (Comma Separated Value) adalah sebuah file teks yang menyimpan data dalam format tabel terstruktur dengan memisahkan nilai-nilai menggunakan koma atau titik koma.

# %% [markdown]
# ## Mode 'r' (Read)

# %%
file = open("data_mahasiswa.csv", "r")
data = file.read()
print(data)
file.close() # tutup file setelah proses membuka file selesai
# Out:
# Nama, NIM, Jurusan
# Rasthian, 222410102000, Teknologi Informasi
# Fathan, 232410103015, Informatika

# %% [markdown]
# ## Mode 'a' (Append)

# %%
file = open('data_mahasiswa.csv', 'a')
# menambahkan data ke file csv dengan fungsi write
file.write('VIan, 232410103022, Informatika\n')
file.close() # tutup file setelah proses menambah data selesai

# membaca file setelah ditambahkan data menggunakan mode 'r'
file = open('data_mahasiswa.csv', 'r')
data = file.read() # membaca file setelah ditambahkan data
print(data)
file.close() # tutup file setelah proses membaca file selesai
# Out:
# VIan, 232410103022, Informatika
# VIan, 232410103022, Informatika

# %% [markdown]
# ## Mode 'w' (Write)

# %%
file = open('data_mahasiswa.csv', 'w')
file.write('Nama : Budiono Siregar\nNIM : 242410104100\nJurusan : Teknik Komputer dan Jaringan\n')
file.close()

# uncomment kode berikut & lihat perbedaannya
# file = open('mahasiswa.txt', 'w') #
# file.write('Nama : Fauzul Akbar\nNIM : 242410101001\nJurusan : Sistem Informasi\n')
# file.close()

file = open('data_mahasiswa.csv', 'r')
data = file.read()
print(data)
file.close()
# Out:
# Nama : Budiono Siregar
# NIM : 242410104100
# Jurusan : Teknik Komputer dan Jaringan

# %% [markdown]
# ### Setiap menggunakan fungsi ```open()``` untuk membuka file, kita juga harus menggunakan fungsi ```close()``` untuk menutup file.
# ### Cara lain agar dalam melakukan File Handling lebih efisien adalah dengan menggunakan statement ```with```. Statement ini memungkinkan kita melakukan File Handling secara efisien, karena setelah kita membuka file maka otomatis akan ditutup jika sudah selesai.

# %%
# Contoh penggunaan with statement
# with open('data_mahasiswa.csv', mode= 'r', mode = 'a') as file:
#     tambah = file.write('topik, 232410103045, Unfirm')
#     data = file.read()
#     print(file.read())
#     print(F"INI DATA {data}")
with open ('data_mahasiswa.csv', 'a') as tambah:
    asprak = tambah.write('topik, 232410103024, Unf')
    nganu = tambah.read()
    print(tambah)   
# with open('data_mahasiswa.csv', 'r') as baca:
#     nganu = baca.read()
#     print(nganu)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       1 # Contoh penggunaan with statement
#       2 # with open('data_mahasiswa.csv', mode= 'r', mode = 'a') as file:
#       3 #     tambah = file.write('topik, 232410103045, Unfirm')
#       4 #     data = file.read()
#       5 #     print(file.read())
#       6 #     print(F"INI DATA {data}")
# ----> 7 with open ('data_mahasiswa.csv', 'a', 'r') as tambah:
#       8     asprak = tambah.write('topik, 232410103024, Unf')
#       9     nganu = tambah.read()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# ## Penerapan statement 'with' dalam File Handling

# %%
# Menulis file dengan with statement menggunakan mode 'w' (write)
with open('data_mahasiswa.csv', 'w') as file:
    file.write('Nama, NIM, Jurusan\n')

# Menambahkan data ke file dengan with statement menggunakan mode 'a' (append)
with open('data_mahasiswa.csv', 'a') as file:
    file.write('Rasthian, 222410102000, Teknologi Informasi\n')
    file.write('Fathan, 232410103015, Informatika')

# Membaca file dengan with statement menggunakan mode 'r' (read)
with open('data_mahasiswa.csv', 'r') as file:
    data = file.read()
    print(data)
# Out:
# Nama, NIM, Jurusan
# Rasthian, 222410102000, Teknologi Informasi
# Fathan, 232410103015, Informatika

# %% [markdown]
# # <b>Data Handling 😽</b>

# %% [markdown]
# ![image 11.png](data:image/png;base64,...)

# %% [markdown]
# <h3>Kalo kalian punya data, kalian bisa ngatur data yang kalian punya. Entah itu mau diurutkan, ditambahin data, dihapus, diedit, dan segala macem. Pake apa kak ngaturnya? pake nanya. Pake pandas lah 🐼 </h3>

# %% [markdown]
# ![Screenshot 2024-11-05 175505.png](data:image/png;base64,...)

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\vian\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vian\appdata\roaming\python\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vian\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vian\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vian\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\vian\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# Dataframe dalam pandas memiliki parameter.Parameter ini adalah data yang akan digunakan untuk membuat DataFrame. Data bisa berupa beberapa tipe, termasuk:
#
# - ndarray: Array NumPy
# - dict: Kamus Python
# - list: Daftar Python
# - series: Series Pandas
# - DataFrame: DataFrame lainnya

# %% [markdown]
# # Membuat data

# %% [markdown]
# ### Data kosong

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Data dengan list satu dimensi

# %%
dataHewan = ['Ayam', 'Badak', 'Sapi', 'Semut']
# df.index += 1
df = pd.DataFrame(dataHewan, columns=['nama hewan'])

print(df)
# print(dataHewan)
# Out:
#   nama hewan
# 0       Ayam
# 1      Badak
# 2       Sapi
# 3      Semut

# %% [markdown]
# ### Data dengan list dua dimensi

# %%
dataStatusHewan = [['Ayam', 'Mati'], ['Badak', 'Hidup'], ['Sapi', 'Mati'], ['Semut', 'Hidup']]
df = pd.DataFrame(dataStatusHewan, columns=(['binatang', 'status']))
df
# print(df)
# Out:
#   binatang status
# 0     Ayam   Mati
# 1    Badak  Hidup
# 2     Sapi   Mati
# 3    Semut  Hidup

# %% [markdown]
# ### Menambakan nama kolom dalam data

# %%
dataOrangMasukSurga = [
    ['Ariski', 22, 'Denmark'],
    ['Athar', 20, 'Japan'],
    ['Eka', 25, 'Finlandia'],
    ['Fauzul', 19, 'Mars'],
    ['Fathan', 23, 'Laos'],
    ['Irvan', 30, 'Qatar'],
    ['Mr. Rasthian', 40, 'Argentina'],
    ['Sapta', 28, 'Portugal'],
    ['Taufik', 27, 'France'],
    ['Tsaqif', 24, 'Norwegia'],
    ['Vian', 26, 'Jombang'],
    ['Zakha', 21, 'Spanyol']
]

header = ['Nama', 'Umur', 'Asal Negara']
df = pd.DataFrame(dataOrangMasukSurga, columns=header)
df
# Out:
#             Nama  Umur Asal Negara
# 0         Ariski    22     Denmark
# 1          Athar    20       Japan
# 2            Eka    25   Finlandia
# 3         Fauzul    19        Mars
# 4         Fathan    23        Laos
# 5          Irvan    30       Qatar
# 6   Mr. Rasthian    40   Argentina
# 7          Sapta    28    Portugal
# 8         Taufik    27      France
# 9         Tsaqif    24    Norwegia
# 10          Vian    26     Jombang
# 11         Zakha    21     Spanyol

# %%
import pandas as pd

# Membuat DataFrame pertama
df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
}, index=['a', 'b', 'c'])

# Membuat DataFrame kedua dengan indeks dan kolom yang berbeda
df2 = pd.DataFrame({
    'B': [7, 8],
    'C': [9, 10]
}, index=['b', 'c'])

# Align df1 dan df2 berdasarkan indeks dan kolom
df1_aligned, df2_aligned = df1.align(df2, join='outer', axis=0)

print(df1_aligned)
print(df2_aligned)
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6
#      B     C
# a  NaN   NaN
# b  7.0   9.0
# c  8.0  10.0

# %% [markdown]
# ### Menggunakan dictionary (langsung ada headernya)

# %%
dataOrangSukses = {
    'Nama' : ['Sapta', 'Ariski', 'Tsaqif', 'Irvan', 'Eka', 'Mr. Rasthian', 'Fauzul', 'Athar', 'Taufik', 'Vian', 'Zakha', 'Fathan'],
    'Perusahaan' : ['Amazon', 'NASA', 'Microsoft', 'Tesla', 'Meta', 'Tokopedia', 'Google', 'Rockstar', 'Shopee', 'Pertamina', 'OVO', 'OpenAI'],
    'Penghasilan ($)' : [10000000, 8500000, 12000000, 20000000, 18000000, 7500000, 16000000, 8000000, 9000000, 11000000, 9500000, 12500000]
}

df = pd.DataFrame(dataOrangSukses)
df
# print(dataOrangSukses) di file.py diawali print
# Out:
#             Nama Perusahaan  Penghasilan ($)
# 0          Sapta     Amazon         10000000
# 1         Ariski       NASA          8500000
# 2         Tsaqif  Microsoft         12000000
# 3          Irvan      Tesla         20000000
# 4            Eka       Meta         18000000
# 5   Mr. Rasthian  Tokopedia          7500000
# 6         Fauzul     Google         16000000
# 7          Athar   Rockstar          8000000
# 8         Taufik     Shopee          9000000
# 9           Vian  Pertamina         11000000
# 10         Zakha        OVO          9500000
# 11        Fathan     OpenAI         12500000

# %% [markdown]
# # Menyimpan ke csv

# %%
# df.index -= 1
df.to_csv('Data_Orang_Tersigma.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # df.index -= 1
# ----> 2 df.to_csv('Data_Orang_Tersigma.csv', index=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Membaca data dari csv

# %% [markdown]
# File csv yang telah dibuat dapat dibaca menggunakan pd.read_csv(*file yang dituju*)

# %%
df = pd.read_csv('Data_Orang_Tersigma.csv')
df
# Out:
#     Unnamed: 0          Nama Perusahaan  Penghasilan ($)
# 0            0         Sapta     Amazon             1000
# 1            1        Ariski       NASA             8500
# 2            2        Tsaqif  Microsoft             1200
# 3            3         Irvan      Tesla             2000
# 4            4           Eka       Meta             1800
# 5            5  Mr. Rasthian  Tokopedia             7500
# 6            6        Fauzul     Google             1600
# 7            7         Athar   Rockstar              800
# 8            8        Taufik     Shopee              900
# 9            9          Vian  Pertamina             1100
# 10          10         Zakha        OVO              950
# 11          11        Fathan     OpenAI             1250

# %% [markdown]
# # Method untuk melihat data

# %% [markdown]
# Berikut adalah beberapa metode penting untuk melihat data:
#
# *   head(): Menampilkan beberapa baris pertama data.
# *   tail(): Menampilkan beberapa baris terakhir data.
# *   info(): Menampilkan ringkasan informasi DataFrame.
# *   describe(): Memberikan statistik ringkas untuk kolom numerik.
#
# Mengubah tipe data menggunakan .astype()

# %%
df.head(5) #Menampilkan 5 baris pertama
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 0   Sapta     Amazon         10000000
# 1  Ariski       NASA          8500000
# 2  Tsaqif  Microsoft         12000000
# 3   Irvan      Tesla         20000000
# 4     Eka       Meta         18000000

# %%
df.tail(5) #Menampilkan 5 baris terakhir
# Out:
#     nomor    Nama Perusahaan  Penghasilan ($)
# 7       8   Athar   Rockstar          8000000
# 8       9  Taufik     Shopee          9000000
# 9      10    Vian  Pertamina         11000000
# 10     11   Zakha        OVO          9500000
# 11     12  Fathan     OpenAI         12500000

# %% [markdown]
# # Mengubah tipe data

# %%
dfubah = df.astype({
    'Nama':'str',
    'Perusahaan':'str',
    'Penghasilan ($)':'int'
})

# %% [markdown]
# # Melihat Informasi data

# %%
dfubah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nama             12 non-null     object
#  1   Perusahaan       12 non-null     object
#  2   Penghasilan ($)  12 non-null     int32
# dtypes: int32(1), object(2)
# memory usage: 372.0+ bytes

# %% [markdown]
# # Melihat ringkasan data

# %%
df.describe()
# Out:
#        Unnamed: 0  Penghasilan ($)
# count   12.000000        12.000000
# mean     5.500000      2383.333333
# std      3.605551      2657.778749
# min      0.000000       800.000000
# 25%      2.750000       987.500000
# 50%      5.500000      1225.000000
# 75%      8.250000      1850.000000
# max     11.000000      8500.000000

# %% [markdown]
# # Menampilkan ukuran data

# %%
df.shape
# Out:
# (12, 4)

# %% [markdown]
# # Menampilkan kolom tertentu

# %%
# print(df.Nama )# Cara pertama
print(df[['Nama', 'Perusahaan']]) # Cara kedua
# Out:
#             Nama Perusahaan
# 0          Sapta     Amazon
# 1         Ariski       NASA
# 2         Tsaqif  Microsoft
# 3          Irvan      Tesla
# 4            Eka       Meta
# 5   Mr. Rasthian  Tokopedia
# 6         Fauzul     Google
# 7          Athar   Rockstar
# 8         Taufik     Shopee
# 9           Vian  Pertamina
# 10         Zakha        OVO
# 11        Fathan     OpenAI

# %% [markdown]
# # FIltering data

# %%
dataOrangSukses.head(5)
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 0   Sapta     Amazon         10000000
# 1  Ariski       NASA          8500000
# 2  Tsaqif  Microsoft         12000000
# 3   Irvan      Tesla         20000000
# 4     Eka       Meta         18000000

# %% [markdown]
# ### Index location (iloc)

# %%
df.iloc[6,3] #baris ketiga, kolom dengan index ke dua
# Out:
# 1600

# %%
df.loc[0:5]
# Out:
#   Unnamed: 0          Nama Perusahaan  Penghasilan ($)
# 0          a         Sapta     Amazon             1000
# 1          1        Ariski       NASA             8500
# 2          2        Tsaqif  Microsoft             1200
# 3          3         Irvan      Tesla             2000
# 4          4           Eka       Meta             1800
# 5          5  Mr. Rasthian  Tokopedia             7500

# %%
df.iloc[3, 0:3] #baris ketiga, kolom dengan index dari 0 sampai sebelum 3
# Out:
# nomor             4
# Nama          Irvan
# Perusahaan    Tesla
# Name: 3, dtype: object

# %%
df.iloc[[2, 4]] #filter berdasarkan baris
# Out:
#   Unnamed: 0    Nama Perusahaan  Penghasilan ($)
# 2          2  Tsaqif  Microsoft             1200
# 4          4     Eka       Meta             1800

# %% [markdown]
# # Merging data

# %% [markdown]
# ### Menggunakan `join()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United', 'Jl. Kalimantan 9']
}

data1 = pd.read_csv('data_mahasiswa.csv')
data2 = pd.read_csv('Data_Orang_Tersigma.csv')

dataJoin = data1.join(data2)
data = dataJoin.to_csv('gabungan 2 data.csv')
baca = pd.read_csv('Data_Orang_Tersigma.csv')
print(baca)
# Out:
#     Unnamed: 0.1   0         Sapta     Amazon  1000  Unnamed: 0          Nama  \
# 0              0   1        Ariski       NASA  8500           0         Sapta
# 1              1   2        Tsaqif  Microsoft  1200           1        Ariski
# 2              2   3         Irvan      Tesla  2000           2        Tsaqif
# 3              3   4           Eka       Meta  1800           3         Irvan
# 4              4   5  Mr. Rasthian  Tokopedia  7500           4           Eka
# 5              5   6        Fauzul     Google  1600           5  Mr. Rasthian
# 6              6   7         Athar   Rockstar   800           6        Fauzul
# 7              7   8        Taufik     Shopee   900           7         Athar
# 8              8   9          Vian  Pertamina  1100           8        Taufik
# 9              9  10         Zakha        OVO   950           9          Vian
# 10            10  11        Fathan     OpenAI  1250          10         Zakha
#
#    Perusahaan  Penghasilan ($)
# 0      Amazon             1000
# 1        NASA             8500
# 2   Microsoft             1200
# 3       Tesla             2000
# 4        Meta             1800
# 5   Tokopedia             7500
# 6      Google             1600
# 7    Rockstar              800
# 8      Shopee              900
# 9   Pertamina             1100
# 10        OVO              950

# %% [markdown]
# ### Menggunakan `concat()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United']
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataJoin = pd.concat([data1, data2], axis=1)
dataJoin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       1 data1 = {
#       2     'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
#       3     'Umur' : [3, 4, 5]
#       4 }
#       6 data2 = {
#       7     'Alamat' : ['Jember', 'Manchester United']
#       8 }
# ---> 10 data1 = pd.DataFrame(data1)
#      11 data2 = pd.DataFrame(data2)
#      13 dataJoin = pd.concat([data1, data2], axis=1)
#
# NameError: name 'pd' is not defined

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United', 'Jl. Kalimantan 9']
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataJoin = pd.concat([data1, data2], axis=0)
dataJoin
# Out:
#       Nama  Umur             Alamat
# 0  Kambing   3.0                NaN
# 1     Sapi   4.0                NaN
# 2   Kerbau   5.0                NaN
# 0      NaN   NaN             Jember
# 1      NaN   NaN  Manchester United
# 2      NaN   NaN   Jl. Kalimantan 9

# %% [markdown]
# ### Menggunakan `merge()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United']
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataMerge = pd.merge(data1, data2, left_index=True, right_index=True)
dataMerge
# Out:
#       Nama  Umur             Alamat
# 0  Kambing     3             Jember
# 1     Sapi     4  Manchester United

# %% [markdown]
# # Update Data

# %%
dataOrangSukses.head(5)
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 0   Sapta     Amazon         10000000
# 1  Ariski       NASA          8500000
# 2  Tsaqif  Microsoft         12000000
# 3   Irvan      Tesla         20000000
# 4     Eka       Meta         18000000

# %% [markdown]
# Misal Eka ganti perusahaan dari Meta ke Amazon

# %% [markdown]
# ### Menggunakan `iloc[]`

# %%
df.iloc[4, 1] = input("masukkan nama pengganti")
print(df.iloc[4,1])
df.to_csv('Data_Orang_Tersigma.csv')
# Out:
# Sogol

# %%
df.head(5)
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 0   Sapta     Amazon         10000000
# 1  Ariski       NASA          8500000
# 2  Tsaqif  Microsoft         12000000
# 3   Irvan      Tesla         20000000
# 4     Eka      Sogol         18000000

# %% [markdown]
# ### Menggunakan `at()`

# %% [markdown]
# Misal Ariski resign dari NASA terus keterima di Netflix

# %%
df.at[4, 'Perusahaan'] = 'Microhard'
df.to_csv('Data_Orang_Tersigma.csv')

# %%
dataOrangSukses.head(5)
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 0   Sapta     Amazon         10000000
# 1  Ariski    Netflix          8500000
# 2  Tsaqif  Microsoft         12000000
# 3   Irvan      Tesla         20000000
# 4     Eka     Amazon         18000000

# %% [markdown]
# # Menghapus data

# %%
database = {
    'Nama':['Aal', 'Ali', 'Alif','Alex'],
    'NIM':[4000, 4001, 4002, 4003],
    'Nilai':[90.0, 90.0, 90.0, 90.0]
}

data = pd.DataFrame(database)
data
# Out:
#    Nama   NIM  Nilai
# 0   Aal  4000   90.0
# 1   Ali  4001   90.0
# 2  Alif  4002   90.0
# 3  Alex  4003   90.0

# %%
dataHapus = df.drop(2)
dataHapus.to_csv('Data_Orang_Tersigma.csv')
dataHapus
# Out:
#     Unnamed: 0          Nama Perusahaan  Penghasilan ($)
# 0            0         Sapta     Amazon             1000
# 1            1        Ariski       NASA             8500
# 3            3         Irvan      Tesla             2000
# 4            4         Sogol  Microhard             1800
# 5            5  Mr. Rasthian  Tokopedia             7500
# 6            6        Fauzul     Google             1600
# 7            7         Athar   Rockstar              800
# 8            8        Taufik     Shopee              900
# 9            9          Vian  Pertamina             1100
# 10          10         Zakha        OVO              950
# 11          11        Fathan     OpenAI             1250

# %% [markdown]
# <h2>Indexnya kacaw le, benerkan dong<h2>

# %%
dataHapus.index = range(1, len(dataHapus) + 1)
dataHapus
# Out:
#     Unnamed: 0          Nama Perusahaan  Penghasilan ($)
# 1            0         Sapta     Amazon             1000
# 2            1        Ariski       NASA             8500
# 3            3         Irvan      Tesla             2000
# 4            4         Sogol  Microhard             1800
# 5            5  Mr. Rasthian  Tokopedia             7500
# 6            6        Fauzul     Google             1600
# 7            7         Athar   Rockstar              800
# 8            8        Taufik     Shopee              900
# 9            9          Vian  Pertamina             1100
# 10          10         Zakha        OVO              950
# 11          11        Fathan     OpenAI             1250

# %% [markdown]
# # SUDAH WAKTUNYA KOAKOOKAOWOAWKOKAWOKA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # NOMOR 1
# Roni merupakan seorang jurnalis di salah satu ukm pada fakultas ilmu kommputer. Dia sedang membuat artikel yang berisi tips sukses dari orang-orang yang pernah berkuliah di fasilkom. Dia sendiri penasaran berapa total penghasilan dari seluruh daftar orang sukses di fasilkom ini. Buatlah sebuah kode yang dapat menghasilkan total penghasilan dari seluruh daftar orang sukses tersebut

# %%
import pandas as pd
dataOrangSukses = {
    'Nama' : ['Sapta', 'Ariski', 'Tsaqif', 'Irvan', 'Eka', 'Mr. Rasthian', 'Fauzul', 'Athar', 'Taufik', 'Vian', 'Zakha', 'Fathan'],
    'Perusahaan' : ['Amazon', 'NASA', 'Microsoft', 'Tesla', 'Meta', 'Tokopedia', 'Google', 'Rockstar', 'Shopee', 'Pertamina', 'OVO', 'OpenAI'],
    'Penghasilan ($)' : [10000000, 8500000, 12000000, 20000000, 18000000, 7500000, 16000000, 8000000, 9000000, 11000000, 9500000, 12500000]
}

data = pd.DataFrame(dataOrangSukses)
# Kodingkan dulu le

total = data['Penghasilan ($)'].sum()
print(total)
# Out:
# 142000000

# %% [markdown]
# # NOMOR 2
# Roni sudah semester 12, namun artikel karangannya belum terbit juga. Dia tiba-tiba penasaran dengan data yang pernah ia cantumkan pada artikelnya. Namun, data penghasilan yang ada pada tersebut telah kadaluarsa. Buatlah sebuah kode yang untuk mengupdate data penghasilan pada data dibawah dengan bertambah sebanyak 20% dari penghasilan sebelumnya.

# %%
dataOrangSukses = {
    'Nama' : ['Sapta', 'Ariski', 'Tsaqif', 'Irvan', 'Eka', 'Mr. Rasthian', 'Fauzul', 'Athar', 'Taufik', 'Vian', 'Zakha', 'Fathan'],
    'Perusahaan' : ['Amazon', 'NASA', 'Microsoft', 'Tesla', 'Meta', 'Tokopedia', 'Google', 'Rockstar', 'Shopee', 'Pertamina', 'OVO', 'OpenAI'],
    'Penghasilan ($)' : [10000000, 8500000, 12000000, 20000000, 18000000, 7500000, 16000000, 8000000, 9000000, 11000000, 9500000, 12500000]
}

# Kodingkan dulu le
data = pd.DataFrame(dataOrangSukses)
data['Penghasilan ($)'] = data['Penghasilan ($)'] * 1.20

print("Data setelah penghasilan diperbarui:")
print(data)
# Out:
# Data setelah penghasilan diperbarui:
#             Nama Perusahaan  Penghasilan ($)
# 0          Sapta     Amazon       12000000.0
# 1         Ariski       NASA       10200000.0
# 2         Tsaqif  Microsoft       14400000.0
# 3          Irvan      Tesla       24000000.0
# 4            Eka       Meta       21600000.0
# 5   Mr. Rasthian  Tokopedia        9000000.0
# 6         Fauzul     Google       19200000.0
# 7          Athar   Rockstar        9600000.0
# 8         Taufik     Shopee       10800000.0
# 9           Vian  Pertamina       13200000.0
# 10         Zakha        OVO       11400000.0
# 11        Fathan     OpenAI       15000000.0

# %% [markdown]
# # NOMOR 3
# Cewe tercantik di fasikom sedang mencari pasangannya, Dia hanya ingin pasangan dari daftar orang ganteng yang ada di fasilkom. Namun, beberapa orang dalam daftar sudah memiliki pasangan. Buatlah sebuah program yang dapat menampilkan daftar orang ganteng yang belum memiliki pasangan untuk membantu cewe tercantik menemukan pasangannya.
#
# *Status true merupakan tanda orang ganteng tersebut masih belum memiliki pasangan

# %%
OrangGanteng = {
    'Nama' : ['Sapta', 'Ariski', 'Tsaqif', 'Irvan', 'Eka', 'Mr. Rasthian', 'Fauzul', 'Athar', 'Taufik', 'Vian', 'Zakha', 'Fathan'],
    'Usia' : [20,20,19,19,19,21,22,20,19,20,21,20],
    'Status' : [True,False,True,True,True,False,True,False,True,False,True,True]
}

data = pd.DataFrame(OrangGanteng)
data

# Kodingkan dulu le
# Out:
#             Nama  Usia  Status
# 0          Sapta    20    True
# 1         Ariski    20   False
# 2         Tsaqif    19    True
# 3          Irvan    19    True
# 4            Eka    19    True
# 5   Mr. Rasthian    21   False
# 6         Fauzul    22    True
# 7          Athar    20   False
# 8         Taufik    19    True
# 9           Vian    20   False
# 10         Zakha    21    True
# 11        Fathan    20    True

# %% [markdown]
# # NOMOR 4
# Buatkan sebuah program yang dapat membuka file "Soal 4 Testing". Selanjutnya buat agar program bisa menampilkan nama, umur, alamat dan jenis kelamin sesuai dengan nama yang diinputkan pengguna dan apabila nama tidak ditemukan tampilkan "Nama tidak ditemukan".
#
# hint = gunakan for dan perkondisian

# %% [markdown]
# contoh penggunaan :
#
# input = Budi
#
# Output =
#
# Nama = Budi
#
# Umur = 24
#
# Alamat = JL. Merpati
#
# Jenis Kelamin = Laki-laki

# %%
#Infokan jawaban
